# %%
import pandas as pd
import geopandas as gpd

# %%
veh = gpd.GeoDataFrame(pd.read_csv('../data/output/crash/all_crash.csv'))
ped = gpd.GeoDataFrame(pd.read_csv('../data/output/crash/pedestrians_crash.csv'))
bic = gpd.GeoDataFrame(pd.read_csv('../data/output/crash/bicycle_crash.csv'))

# %%
ped.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'direction', 'is_pass', 'is_bidi',
#        'geometry', 'Type of Travel_x', 'Intersection Type_x', 'Zone ID_x',
#        'Zone Name_x', 'Zone Is Pass-Through_x', 'Zone Direction (degrees)_x',
#        'Zone is Bi-Direction_x', 'Day Type_x', 'Day Part_x',
#        'Average Daily Zone Traffic (StL Index)_x', 'Avg Trip Duration (sec)_x',
#        'Avg All Trip Duration (sec)_x', 'Avg Trip Length (mi)_x',
#        'Avg All Trip Length (mi)_x', 'pedestrian_volume', 'Type of Travel_y',
#        'Intersection Type_y', 'Zone ID_y', 'Zone Name_y',
#        'Zone Is Pass-Through_y', 'Zone Direction (degrees)_y',
#        'Zone is Bi-Direction_y', 'Day Type_y', 'Day Part_y',
#        'Average Daily Zone Traffic (StL Index)_y', 'Avg Trip Duration (sec)_y',
#        'Avg All Trip Duration (sec)_y', 'Avg Trip Length (mi)_y',
#        'Avg All Trip Length (mi)_y', 'bicycle_volume', 'Type of Travel',
#        'Home and Work Filter', 'Intersection Type', 'Zone ID', 'Zone Name',
#        'Zone Is Pass-Through', 'Zone Direction (degrees)',
#        'Zone is Bi-Direction', 'Day Type', 'Day Part',
#        'Average Daily Zone Traffic (StL Volume)', 'Avg Trip Duration (sec)',
#        'Avg All Trip Duration (sec)', 'Avg Trip Length (mi)',
#        'Avg All Trip Length (mi)', 'vehicle_volume', 'crash_count_x',
#        'crash_count_y', 'total_crash'],
#       dtype='object')

# %%
def mev(aadt, num_years):
    mev = (aadt*365*num_years)/1000000
    return mev

# %%
# Calculate mev to have scaled traffic value https://safety.fhwa.dot.gov/local_rural/training/fhwasa14072/sec4.cfm
ped['mev'] = ((ped['vehicle_volume'] * ped['pedestrian_volume'])*365*11)/1000000
bic['mev'] = ((bic['vehicle_volume'] * bic['bicycle_volume'])*365*11)/1000000
veh['mev_ped'] = ((veh['vehicle_volume'] * veh['pedestrian_volume'])*365*11)/1000000
veh['mev_bic'] = ((veh['vehicle_volume'] * veh['bicycle_volume'])*365*11)/1000000


# Crash Rate
ped['crash_rate'] = ped['total_crash']/ped['mev']
bic['crash_rate'] = bic['total_crash']/bic['mev']

# %%
ax = ped['crash_rate'].plot.hist(bins=50, alpha=0.5)
ax.set_xticklabels(bic['crash_rate'], rotation=90)
ax

# %%
ax = bic['crash_rate'].plot.hist(bins=50, alpha=0.5)
ax.set_xticklabels(bic['crash_rate'], rotation=90)
ax
