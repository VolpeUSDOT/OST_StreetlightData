# %% [markdown]
# ### Data Integration with StreetLight Zones (Crashes - Philadelphia)

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import os

data_root = r'C:\Users\Daniel.Flynn\Documents\git\stld\data'

# %% [markdown]
# ### Maintaining Projections with Simple Functions

# %%
def get_proj(gdf):
    # Retrieve coord from layer
    coords = gdf.crs['init']
    return coords
    

def set_proj(gdf, espg_coord = 'espg:4326'):
    # Set coordinate systems / meant to be used with function get_proj to set all coords to one thing.
    gdf.crs = {'init': espg_coord}

# %% [markdown]
# ### Read in StreetLight Data

# %%
# Load in StreetLight Zones
stl = gpd.read_file(os.path.join(data_root, 'stl_data/128523_Pedestrians_06092020/Shapefile/128523_Pedestrians_06092020_zone_activity.shp'))
print('STL Data Extent:', stl.shape[0], 'Records')

# Read in the csv information about traffic metrics from streetlight

# Pedestrians
ped = pd.read_csv(os.path.join(data_root, 'stl_data/128523_Pedestrians_06092020/128523_Pedestrians_06092020_za_ped.csv'))

# Bicyclists
bic = pd.read_csv(os.path.join(data_root, 'stl_data/128525_Bicyclists_06092020/128525_Bicyclists_06092020_za_bike.csv'))

# Vehicles
veh = pd.read_csv(os.path.join(data_root, 'stl_data/128526_Vehicle_06092020/128526_Vehicle_06092020_za_all.csv'))
print('File Number of Records', ped.shape[0], bic.shape[0], veh.shape[0])
# Out:
# STL Data Extent: 50 Records
# File Number of Records 900 900 900

# %%
bic['Average Daily Zone Traffic (StL Index)'].head()
# Out:
# 0    3363
# 1      62
# 2     684
# 3     930
# 4    1414
# Name: Average Daily Zone Traffic (StL Index), dtype: int64

# %%
bic
# Out:
#       Type of Travel  Intersection Type  Zone ID  \
# 0    Personal - Bike  Trip Pass-Through    14162
# 18   Personal - Bike  Trip Pass-Through    14583
# 36   Personal - Bike  Trip Pass-Through    15034
# 54   Personal - Bike  Trip Pass-Through    15717
# 72   Personal - Bike  Trip Pass-Through    15996
# 90   Personal - Bike  Trip Pass-Through    16990
# 108  Personal - Bike  Trip Pass-Through    18361
# 126  Personal - Bike  Trip Pass-Through    19185
# 144  Personal - Bike  Trip Pass-Through    19864
# 162  Personal - Bike  Trip Pass-Through    20186
# 180  Personal - Bike  Trip Pass-Through    20214
# 198  Personal - Bike  Trip Pass-Through    20311
# 216  Personal - Bike  Trip Pass-Through    20388
# 234  Personal - Bike  Trip Pass-Through    20498
# 252  Personal - Bike  Trip Pass-Through    20584
# 270  Personal - Bike  Trip Pass-Through    20646
# 288  Personal - Bike  Trip Pass-Through    20660
# 306  Personal - Bike  Trip Pass-Through    20697
# 324  Personal - Bike  Trip Pass-Through    20703
# 342  Personal - Bike  Trip Pass-Through    20716
# 360  Personal - Bike  Trip Pass-Through    20743
# 378  Personal - Bike  Trip Pass-Through    20780
# 396  Personal - Bike  Trip Pass-Through    20831
# 414  Personal - Bike  Trip Pass-Through    20840
# 432  Personal - Bike  Trip Pass-Through    20842
# 450  Personal - Bike  Trip Pass-Through    20900
# 468  Personal - Bike  Trip Pass-Through    20920
# 486  Personal - Bike  Trip Pass-Through    20944
# 504  Personal - Bike  Trip Pass-Through    20947
# 522  Personal - Bike  Trip Pass-Through    20973
# 540  Personal - Bike  Trip Pass-Through    20999
# 558  Personal - Bike  Trip Pass-Through    21014
# 576  Personal - Bike  Trip Pass-Through    21017
# 594  Personal - Bike  Trip Pass-Through    21049
# 612  Personal - Bike  Trip Pass-Through    21074
# 630  Personal - Bike  Trip Pass-Through    21075
# 648  Personal - Bike  Trip Pass-Through    21102
# 666  Personal - Bike  Trip Pass-Through    21107
# 684  Personal - Bike  Trip Pass-Through    21119
# 702  Personal - Bike  Trip Pass-Through    21134
# 720  Personal - Bike  Trip Pass-Through    21155
# 738  Personal - Bike  Trip Pass-Through    21168
# 756  Personal - Bike  Trip Pass-Through    21185
# 774  Personal - Bike  Trip Pass-Through    21186
# 792  Personal - Bike  Trip Pass-Through    21217
# 810  Personal - Bike  Trip Pass-Through    21357
# 828  Personal - Bike  Trip Pass-Through    21393
# 846  Personal - Bike  Trip Pass-Through    26922
# 864  Personal - Bike  Trip Pass-Through    26996
# 882  Personal - Bike  Trip Pass-Through    26998
#
#                                          Zone Name Zone Is Pass-Through  \
# 0    50 Philadelphia Selections - 01152020 Zone 08                  yes
# 18   50 Philadelphia Selections - 01152020 Zone 06                  yes
# 36   50 Philadelphia Selections - 01152020 Zone 11                  yes
# 54   50 Philadelphia Selections - 01152020 Zone 09                  yes
# 72   50 Philadelphia Selections - 01152020 Zone 07                  yes
# 90   50 Philadelphia Selections - 01152020 Zone 45                  yes
# 108  50 Philadelphia Selections - 01152020 Zone 10                  yes
# 126  50 Philadelphia Selections - 01152020 Zone 44                  yes
# 144  50 Philadelphia Selections - 01152020 Zone 32                  yes
# 162  50 Philadelphia Selections - 01152020 Zone 04                  yes
# 180  50 Philadelphia Selections - 01152020 Zone 46                  yes
# 198  50 Philadelphia Selections - 01152020 Zone 47                  yes
# 216  50 Philadelphia Selections - 01152020 Zone 48                  yes
# 234  50 Philadelphia Selections - 01152020 Zone 05                  yes
# 252  50 Philadelphia Selections - 01152020 Zone 01                  yes
# 270  50 Philadelphia Selections - 01152020 Zone 35                  yes
# 288  50 Philadelphia Selections - 01152020 Zone 36                  yes
# 306  50 Philadelphia Selections - 01152020 Zone 37                  yes
# 324  50 Philadelphia Selections - 01152020 Zone 02                  yes
# 342  50 Philadelphia Selections - 01152020 Zone 38                  yes
# 360  50 Philadelphia Selections - 01152020 Zone 39                  yes
# 378  50 Philadelphia Selections - 01152020 Zone 03                  yes
# 396  50 Philadelphia Selections - 01152020 Zone 40                  yes
# 414  50 Philadelphia Selections - 01152020 Zone 41                  yes
# 432  50 Philadelphia Selections - 01152020 Zone 42                  yes
# 450  50 Philadelphia Selections - 01152020 Zone 12                  yes
# 468  50 Philadelphia Selections - 01152020 Zone 13                  yes
# 486  50 Philadelphia Selections - 01152020 Zone 14                  yes
# 504  50 Philadelphia Selections - 01152020 Zone 15                  yes
# 522  50 Philadelphia Selections - 01152020 Zone 16                  yes
# 540  50 Philadelphia Selections - 01152020 Zone 17                  yes
# 558  50 Philadelphia Selections - 01152020 Zone 18                  yes
# 576  50 Philadelphia Selections - 01152020 Zone 19                  yes
# 594  50 Philadelphia Selections - 01152020 Zone 21                  yes
# 612  50 Philadelphia Selections - 01152020 Zone 22                  yes
# 630  50 Philadelphia Selections - 01152020 Zone 23                  yes
# 648  50 Philadelphia Selections - 01152020 Zone 24                  yes
# 666  50 Philadelphia Selections - 01152020 Zone 25                  yes
# 684  50 Philadelphia Selections - 01152020 Zone 26                  yes
# 702  50 Philadelphia Selections - 01152020 Zone 27                  yes
# 720  50 Philadelphia Selections - 01152020 Zone 28                  yes
# 738  50 Philadelphia Selections - 01152020 Zone 29                  yes
# 756  50 Philadelphia Selections - 01152020 Zone 30                  yes
# 774  50 Philadelphia Selections - 01152020 Zone 50                  yes
# 792  50 Philadelphia Selections - 01152020 Zone 31                  yes
# 810  50 Philadelphia Selections - 01152020 Zone 33                  yes
# 828  50 Philadelphia Selections - 01152020 Zone 34                  yes
# 846  50 Philadelphia Selections - 01152020 Zone 43                  yes
# 864  50 Philadelphia Selections - 01152020 Zone 20                  yes
# 882  50 Philadelphia Selections - 01152020 Zone 49                  yes
#
#      Zone Direction (degrees) Zone is Bi-Direction            Day Type  \
# 0                         NaN                   no  0: All Days (M-Su)
# 18                        NaN                   no  0: All Days (M-Su)
# 36                        NaN                   no  0: All Days (M-Su)
# 54                        NaN                   no  0: All Days (M-Su)
# 72                        NaN                   no  0: All Days (M-Su)
# 90                        NaN                   no  0: All Days (M-Su)
# 108                       NaN                   no  0: All Days (M-Su)
# 126                       NaN                   no  0: All Days (M-Su)
# 144                       NaN                   no  0: All Days (M-Su)
# 162                       NaN                   no  0: All Days (M-Su)
# 180                       NaN                   no  0: All Days (M-Su)
# 198                       NaN                   no  0: All Days (M-Su)
# 216                       NaN                   no  0: All Days (M-Su)
# 234                       NaN                   no  0: All Days (M-Su)
# 252                       NaN                   no  0: All Days (M-Su)
# 270                       NaN                   no  0: All Days (M-Su)
# 288                       NaN                   no  0: All Days (M-Su)
# 306                       NaN                   no  0: All Days (M-Su)
# 324                       NaN                   no  0: All Days (M-Su)
# 342                       NaN                   no  0: All Days (M-Su)
# 360                       NaN                   no  0: All Days (M-Su)
# 378                       NaN                   no  0: All Days (M-Su)
# 396                       NaN                   no  0: All Days (M-Su)
# 414                       NaN                   no  0: All Days (M-Su)
# 432                       NaN                   no  0: All Days (M-Su)
# 450                       NaN                   no  0: All Days (M-Su)
# 468                       NaN                   no  0: All Days (M-Su)
# 486                       NaN                   no  0: All Days (M-Su)
# 504                       NaN                   no  0: All Days (M-Su)
# 522                       NaN                   no  0: All Days (M-Su)
# 540                       NaN                   no  0: All Days (M-Su)
# 558                       NaN                   no  0: All Days (M-Su)
# 576                       NaN                   no  0: All Days (M-Su)
# 594                       NaN                   no  0: All Days (M-Su)
# 612                       NaN                   no  0: All Days (M-Su)
# 774                   4.0                       4.0            5609  21186
# 792                   4.2                       4.2            5308  21217
# 810                   4.8                       4.8            5009  21357
# 828                   4.0                       4.0            2878  21393
# 846                   5.2                       5.2            1814  26922
# 864                   4.3                       4.3            6391  26996
# 882                   4.5                       4.5            5185  26998

# %%
veh['vehicle_volume'] = veh['Average Daily Zone Traffic (StL Volume)']
bic['bicycle_volume'] = bic['Average Daily Zone Traffic (StL Index)']
ped['pedestrian_volume'] = ped['Average Daily Zone Traffic (StL Index)']

# %% [markdown]
# ### Filter Based on Aggregates for all day/all day parts

# %%
# Get general aggregate terms for each mode
ped = ped.loc[ped['Day Type'] == '0: All Days (M-Su)']
ped = ped.loc[ped['Day Part'] == '0: All Day (12am-12am)']

bic = bic.loc[bic['Day Type'] == '0: All Days (M-Su)']
bic = bic.loc[bic['Day Part'] == '0: All Day (12am-12am)']

veh = veh.loc[veh['Day Type'] == '0: All Days (M-Su)']
veh = veh.loc[veh['Day Part'] == '0: All Day (12am-12am)']

print('Pedestrian Count:', ped.shape[0], '\nBicycle Count', bic.shape[0], '\nVehicle Count', veh.shape[0])
# Out:
# Pedestrian Count: 50
# Bicycle Count 50
# Vehicle Count 50

# %% [markdown]
# ### Add ID Field and Tabular Join on the Common Field

# %%
# Create a common id field to join on
ped['id'] = ped['Zone ID']
bic['id'] = bic['Zone ID']
veh['id'] = veh['Zone ID']

# Merge bicycle and pedestrian data on the id field to have all the information
ped_stl = stl.merge(ped, on='id')
ped_bic_stl = ped_stl.merge(bic, on='id')
ped_bic_veh = ped_bic_stl.merge(veh, on='id')

print(ped_bic_veh.shape[0])
# Write it out to file if necessary 
# ped_bic_stl.to_file('../data/ped_bicycle_stl.shp')

ped_bic_veh.columns
# Out:
# 50
# Index(['id', 'name', 'direction', 'is_pass', 'is_bidi', 'geometry',
#        'Type of Travel_x', 'Intersection Type_x', 'Zone ID_x', 'Zone Name_x',
#        'Zone Is Pass-Through_x', 'Zone Direction (degrees)_x',
#        'Zone is Bi-Direction_x', 'Day Type_x', 'Day Part_x',
#        'Average Daily Zone Traffic (StL Index)_x', 'Avg Trip Duration (sec)_x',
#        'Avg All Trip Duration (sec)_x', 'Avg Trip Length (mi)_x',
#        'Avg All Trip Length (mi)_x', 'pedestrian_volume', 'Type of Travel_y',
#        'Intersection Type_y', 'Zone ID_y', 'Zone Name_y',
#        'Zone Is Pass-Through_y', 'Zone Direction (degrees)_y',
#        'Zone is Bi-Direction_y', 'Day Type_y', 'Day Part_y',
#        'Average Daily Zone Traffic (StL Index)_y', 'Avg Trip Duration (sec)_y',
#        'Avg All Trip Duration (sec)_y', 'Avg Trip Length (mi)_y',
#        'Avg All Trip Length (mi)_y', 'bicycle_volume', 'Type of Travel',
#        'Home and Work Filter', 'Intersection Type', 'Zone ID', 'Zone Name',
#        'Zone Is Pass-Through', 'Zone Direction (degrees)',
#        'Zone is Bi-Direction', 'Day Type', 'Day Part',
#        'Average Daily Zone Traffic (StL Volume)', 'Avg Trip Duration (sec)',
#        'Avg All Trip Duration (sec)', 'Avg Trip Length (mi)',
#        'Avg All Trip Length (mi)', 'vehicle_volume'],
#       dtype='object')

# %% [markdown]
# ### Read in Crash Data

# %%
# 2007 to 2017 data is found on the open philly data website / 2018 crash data is available from PENDOT
# all_crash_2007_2017 = gpd.read_file('../data/crash/all/crash_data_collision_crash_2007_2017.shp')
all_crash_2018 = gpd.read_file(os.path.join(data_root, 'crash/all/crash_2018.shp'))

all_crash_2019 = gpd.read_file(os.path.join(data_root, 'crash/all/crash_201(.shp'))

#bic_crash_2007_2017 = gpd.read_file('../data/crash/Bicycle_2007_2017_Crash.shp')
#bic_crash_2018 = gpd.read_file('../data/crash/Bicycle_2018_Crash.shp')

#ped_crash_2007_2017 = gpd.read_file('../data/crash/Ped_2007_2017_Crash.shp')
#ped_crash_2018 = gpd.read_file('../data/crash/Ped_2018_Crash.shp')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: C:\Users\Daniel.Flynn\Documents\git\stld\data\crash/all/crash_201(.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-15-de04f37c167d> in <module>
#       3 all_crash_2018 = gpd.read_file(os.path.join(data_root, 'crash/all/crash_2018.shp'))
#       4
# ----> 5 all_crash_2019 = gpd.read_file(os.path.join(data_root, 'crash/all/crash_201(.shp'))
#       6
#       7 #bic_crash_2007_2017 = gpd.read_file('../data/crash/Bicycle_2007_2017_Crash.shp')
#
# ~\Anaconda3\envs\StlData\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      74
#      75     with fiona_env():
# ---> 76         with reader(path_or_bytes, **kwargs) as features:
#      77
#      78             # In a future Fiona release the crs attribute of features will
#
# ~\Anaconda3\envs\StlData\lib\site-packages\fiona\env.py in wrapper(*args, **kwargs)
#     394     def wrapper(*args, **kwargs):
#     395         if local._env:
# --> 396             return f(*args, **kwargs)
#     397         else:
#     398             if isinstance(args[0], str):
#
# ~\Anaconda3\envs\StlData\lib\site-packages\fiona\__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     251         if mode in ('a', 'r'):
#     252             c = Collection(path, mode, driver=driver, encoding=encoding,
# --> 253                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     254         elif mode == 'w':
#     255             if schema:
#
# ~\Anaconda3\envs\StlData\lib\site-packages\fiona\collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     157             if self.mode == 'r':
#     158                 self.session = Session()
# --> 159                 self.session.start(self, **kwargs)
#     160             elif self.mode in ('a', 'w'):
#     161                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: C:\Users\Daniel.Flynn\Documents\git\stld\data\crash/all/crash_201(.shp: No such file or directory

# %% [markdown]
# ### Aligning the Coordinate Systems

# %%
# Defining Coordinate systems to make sure everything is in the same one.
coord = [all_crash_2007_2017, all_crash_2018, bic_crash_2007_2017, bic_crash_2018, ped_crash_2007_2017, ped_crash_2018]
main = ped_bic_veh
print('Coordinate system', main.crs)
main_coords = get_proj(main)

for i in coord:
    print('Before', i.crs)
    set_proj(i, espg_coord = main_coords)
    print('After', i.crs)
# Out:
# Coordinate system {'init': 'epsg:4326'}
# Before {'init': 'epsg:4326'}
# After {'init': 'epsg:4326'}
# Before {}
# After {'init': 'epsg:4326'}
# Before {'init': 'epsg:4326'}
# After {'init': 'epsg:4326'}
# Before {}
# After {'init': 'epsg:4326'}
# Before {'init': 'epsg:4326'}
# After {'init': 'epsg:4326'}
# Before {}
# After {'init': 'epsg:4326'}

# %% [markdown]
# ### 2007 to 2017 Crashes

# %%
# Conduct a spatial join using geopandas
ped_bic_veh_crash_stl = gpd.sjoin(all_crash_2007_2017, ped_bic_veh, op='within')

# Geopandas produces a ton of duplicates for some reason (Trying to figure out stil.. )
# A work around for this is to filer based on the unique id of the crash
ped_bic_veh_crash_stl = ped_bic_veh_crash_stl.drop_duplicates(subset='crn', keep="last")
print(ped_bic_veh_crash_stl.shape[0])

# Create a crash event for one
ped_bic_veh_crash_stl['cevent']=1


dfpivot = pd.pivot_table(ped_bic_veh_crash_stl,index='name',columns='cevent',aggfunc={'cevent':len})
dfpivot.columns = dfpivot.columns.droplevel()
dfpivot.columns = ['crash_count_2007_2017']
dfpivot['name'] = dfpivot.index
dfpivot.index.names = ['idx_crash']
print(dfpivot.shape[0], 'records')
print('Number of Null Records', dfpivot['crash_count_2007_2017'].isna().sum())
dfpivot.head()
# Out:
# 876
# 50 records
# Number of Null Records 0
#                                                crash_count_2007_2017  \
# idx_crash
# 50 Philadelphia Selections - 01152020 Zone 01                      6
# 50 Philadelphia Selections - 01152020 Zone 02                     11
# 50 Philadelphia Selections - 01152020 Zone 03                     12
# 50 Philadelphia Selections - 01152020 Zone 04                     16
# 50 Philadelphia Selections - 01152020 Zone 05                     20
#
#                                                                                         name
# idx_crash
# 50 Philadelphia Selections - 01152020 Zone 01  50 Philadelphia Selections - 01152020 Zone 01
# 50 Philadelphia Selections - 01152020 Zone 02  50 Philadelphia Selections - 01152020 Zone 02
# 50 Philadelphia Selections - 01152020 Zone 03  50 Philadelphia Selections - 01152020 Zone 03
# 50 Philadelphia Selections - 01152020 Zone 04  50 Philadelphia Selections - 01152020 Zone 04
# 50 Philadelphia Selections - 01152020 Zone 05  50 Philadelphia Selections - 01152020 Zone 05

# %%
dfpivot.to_csv('../data/temp/dfpivot_test_data_all_crashes.csv')

# %% [markdown]
# ### 2018 Crashes

# %%
# Conduct a spatial join using geopandas
ped_bic_veh_crash_stl = gpd.sjoin(all_crash_2018, ped_bic_veh, op='within')

# Geopandas produces a ton of duplicates for some reason (Trying to figure out stil.. )
# A work around for this is to filer based on the unique id of the crash
ped_bic_veh_crash_stl = ped_bic_veh_crash_stl.drop_duplicates(subset='CRN', keep="last")
print(ped_bic_veh_crash_stl.shape[0])

# Create a crash event for one
ped_bic_veh_crash_stl['cevent']=1


dfpivot2 = pd.pivot_table(ped_bic_veh_crash_stl,index='name',columns='cevent',aggfunc={'cevent':len})
dfpivot2.columns = dfpivot2.columns.droplevel()
dfpivot2.columns = ['crash_count_2018']
dfpivot2['name'] = dfpivot2.index
dfpivot2.index.names = ['idx_crash']
print(dfpivot2.shape[0], 'records')
print('Number of Null Records', dfpivot2['crash_count_2018'].isna().sum())
dfpivot2.head()
# Out:
# 145
# 40 records
# Number of Null Records 0
#                                                crash_count_2018  \
# idx_crash
# 50 Philadelphia Selections - 01152020 Zone 01                 2
# 50 Philadelphia Selections - 01152020 Zone 03                 1
# 50 Philadelphia Selections - 01152020 Zone 04                 1
# 50 Philadelphia Selections - 01152020 Zone 05                 5
# 50 Philadelphia Selections - 01152020 Zone 06                10
#
#                                                                                         name
# idx_crash
# 50 Philadelphia Selections - 01152020 Zone 01  50 Philadelphia Selections - 01152020 Zone 01
# 50 Philadelphia Selections - 01152020 Zone 03  50 Philadelphia Selections - 01152020 Zone 03
# 50 Philadelphia Selections - 01152020 Zone 04  50 Philadelphia Selections - 01152020 Zone 04
# 50 Philadelphia Selections - 01152020 Zone 05  50 Philadelphia Selections - 01152020 Zone 05
# 50 Philadelphia Selections - 01152020 Zone 06  50 Philadelphia Selections - 01152020 Zone 06

# %% [markdown]
# ### Put it together

# %%
first_join = ped_bic_veh.merge(dfpivot, on='name', how='left')
print('Number of Null Records', first_join['crash_count_2007_2017'].isna().sum())
print('Number of Records', first_join.shape[0])
# Out:
# Number of Null Records 0
# Number of Records 50

# %%
second_join = first_join.merge(dfpivot2, on='name', how='left')
print('Number of Null Records for 2018', second_join['crash_count_2018'].isna().sum())
print('Number of Null Records for 2007 - 2017', second_join['crash_count_2007_2017'].isna().sum())
print('First Join', first_join.shape[0], '\nSecond_Join', second_join.shape[0])
# Out:
# Number of Null Records for 2018 10
# Number of Null Records for 2007 - 2017 0
# First Join 50
# Second_Join 50

# %%
second_join.head()
# Out:
#         id                                           name direction  is_pass  \
# 0  14162.0  50 Philadelphia Selections - 01152020 Zone 08      None        1
# 1  14583.0  50 Philadelphia Selections - 01152020 Zone 06      None        1
# 2  15034.0  50 Philadelphia Selections - 01152020 Zone 11      None        1
# 3  15717.0  50 Philadelphia Selections - 01152020 Zone 09      None        1
# 4  15996.0  50 Philadelphia Selections - 01152020 Zone 07      None        1
#
#    is_bidi                                           geometry  \
# 0        0  POLYGON ((-75.15398722513029 39.9970613520998,...
# 1        0  POLYGON ((-75.1545904552852 39.9942178225945, ...
# 2        0  POLYGON ((-75.1552728356728 39.9911325607192, ...
# 3        0  POLYGON ((-75.15627807447351 39.9865628994583,...
# 4        0  POLYGON ((-75.1566156808689 39.9849782895165, ...
#
#         Type of Travel_x Intersection Type_x  Zone ID_x  \
# 0  Personal - Pedestrian   Trip Pass-Through      14162
# 1  Personal - Pedestrian   Trip Pass-Through      14583
# 2  Personal - Pedestrian   Trip Pass-Through      15034
# 3  Personal - Pedestrian   Trip Pass-Through      15717
# 4  Personal - Pedestrian   Trip Pass-Through      15996
#
#                                      Zone Name_x  ...            Day Type  \
# 0  50 Philadelphia Selections - 01152020 Zone 08  ...  0: All Days (M-Su)
# 1  50 Philadelphia Selections - 01152020 Zone 06  ...  0: All Days (M-Su)
# 2  50 Philadelphia Selections - 01152020 Zone 11  ...  0: All Days (M-Su)
# 3  50 Philadelphia Selections - 01152020 Zone 09  ...  0: All Days (M-Su)
# 4  50 Philadelphia Selections - 01152020 Zone 07  ...  0: All Days (M-Su)
#
#                  Day Part Average Daily Zone Traffic (StL Volume)  \
# 0  0: All Day (12am-12am)                                  139167
# 1  0: All Day (12am-12am)                                  143814
# 2  0: All Day (12am-12am)                                  112413
# 3  0: All Day (12am-12am)                                  112563
# 4  0: All Day (12am-12am)                                  120296
#
#   Avg Trip Duration (sec) Avg All Trip Duration (sec)  Avg Trip Length (mi)  \
# 0                    3035                        3495                  14.8
# 1                    3030                        3481                  13.7
# 2                    2976                        3470                  12.5
# 3                    2872                        3452                  11.3
# 4                    2830                        3428                  11.1
#
#    Avg All Trip Length (mi)  vehicle_volume  crash_count_2007_2017  \
# 0                      16.8          139167                     19
# 1                      15.8          143814                     43
# 2                      15.0          112413                     21
# 3                      14.1          112563                     30
# 4                      14.0          120296                     36
#
#    crash_count_2018
# 0               5.0
# 1              10.0
# 2               3.0
# 3               3.0
# 4               9.0
#
# [5 rows x 54 columns]

# %%
# Fill nan values for adding
second_join['crash_count_2007_2017'].fillna(0, inplace = True)
second_join['crash_count_2018'].fillna(0, inplace = True)

# Add crash counts together
second_join['total_crash'] = second_join['crash_count_2007_2017'] + second_join['crash_count_2018']
second_join.sort_values(by='total_crash',ascending=False).head()

# Count null values
print('Total Null Values', second_join['total_crash'].isna().sum())
# Out:
# Total Null Values 0

# %%
# To csv to check it out
second_join.to_csv('../data/output/crash/all_crash.csv')

# %% [markdown]
# ### Pedestrians

# %%
# Conduct a spatial join using geopandas
ped_bic_veh_crash_stl = gpd.sjoin(ped_crash_2007_2017, ped_bic_veh, op='within')

# Geopandas produces a ton of duplicates for some reason (Trying to figure out stil.. )
# A work around for this is to filer based on the unique id of the crash
ped_bic_veh_crash_stl = ped_bic_veh_crash_stl.drop_duplicates(subset='crn', keep="last")

# Create a crash event for one
ped_bic_veh_crash_stl['cevent']=1

dfpivot = pd.pivot_table(ped_bic_veh_crash_stl,index='name',columns='cevent',aggfunc={'cevent':len})
dfpivot.columns = dfpivot.columns.droplevel()
dfpivot.columns = ['crash_count']
dfpivot['name'] = dfpivot.index
dfpivot.index.names = ['idx_crash']
print('dfpivot', dfpivot.shape[0], 'records')


# Conduct a spatial join using geopandas
ped_bic_veh_crash_stl = gpd.sjoin(ped_crash_2018, ped_bic_veh, op='within')

# Geopandas produces a ton of duplicates for some reason (Trying to figure out stil.. )
# A work around for this is to filer based on the unique id of the crash
ped_bic_veh_crash_stl = ped_bic_veh_crash_stl.drop_duplicates(subset='CRN', keep="last")

# Create a crash event for one
ped_bic_veh_crash_stl['cevent']=1


dfpivot2 = pd.pivot_table(ped_bic_veh_crash_stl,index='name',columns='cevent',aggfunc={'cevent':len})
dfpivot2.columns = dfpivot2.columns.droplevel()
dfpivot2.columns = ['crash_count']
dfpivot2['name'] = dfpivot2.index
dfpivot2.index.names = ['idx_crash']
print('dfpivot2', dfpivot2.shape[0], 'records')


first_join = ped_bic_veh.merge(dfpivot, on='name', how='left')
second_join = first_join.merge(dfpivot2, on='name', how='left')

# Fill NaN values to add
second_join['crash_count_x'].fillna(0, inplace = True)
second_join['crash_count_y'].fillna(0, inplace = True)


print('\nFirst Join', first_join.shape[0], 'Records', '\nSecond_Join', second_join.shape[0], 'Records')

second_join['total_crash'] = second_join['crash_count_x'] + second_join['crash_count_y']
second_join.sort_values(by='total_crash',ascending=False).head()
second_join['total_crash'].isna().sum()
# Out:
# dfpivot 44 records
# dfpivot2 25 records
#
# First Join 50 Records
# Second_Join 50 Records
# C:\Users\Coleman.Shepard.ctr\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\function_base.py:2167: RuntimeWarning: invalid value encountered in ? (vectorized)
#   outputs = ufunc(*inputs)
# 0

# %%
second_join.to_csv('../data/output/crash/pedestrians_crash.csv')

# %% [markdown]
# ### Bicycles

# %%
# Conduct a spatial join using geopandas
ped_bic_veh_crash_stl = gpd.sjoin(bic_crash_2007_2017, ped_bic_veh, op='within')

# Geopandas produces a ton of duplicates for some reason (Trying to figure out stil.. )
# A work around for this is to filer based on the unique id of the crash
ped_bic_veh_crash_stl = ped_bic_veh_crash_stl.drop_duplicates(subset='crn', keep="last")

# Create a crash event for one
ped_bic_veh_crash_stl['cevent']=1

dfpivot = pd.pivot_table(ped_bic_veh_crash_stl,index='name',columns='cevent',aggfunc={'cevent':len})
dfpivot.columns = dfpivot.columns.droplevel()
dfpivot.columns = ['crash_count']
dfpivot['name'] = dfpivot.index
dfpivot.index.names = ['idx_crash']
print('dfpivot', dfpivot.shape[0], 'records')


# Conduct a spatial join using geopandas
ped_bic_veh_crash_stl = gpd.sjoin(bic_crash_2018, ped_bic_veh, op='within')

# Geopandas produces a ton of duplicates for some reason (Trying to figure out stil.. )
# A work around for this is to filer based on the unique id of the crash
ped_bic_veh_crash_stl = ped_bic_veh_crash_stl.drop_duplicates(subset='CRN', keep="last")
print(ped_bic_veh_crash_stl.shape[0])

# Create a crash event for one
ped_bic_veh_crash_stl['cevent']=1


dfpivot2 = pd.pivot_table(ped_bic_veh_crash_stl,index='name',columns='cevent',aggfunc={'cevent':len})
dfpivot2.columns = dfpivot2.columns.droplevel()
dfpivot2.columns = ['crash_count']
dfpivot2['name'] = dfpivot2.index
dfpivot2.index.names = ['idx_crash']
print('dfpivot2', dfpivot2.shape[0], 'records')


first_join = ped_bic_veh.merge(dfpivot, on='name', how='left')
second_join = first_join.merge(dfpivot2, on='name', how='left')
print('First Join', first_join.shape[0], '\nSecond_Join', second_join.shape[0])

# Fill NaN values to add
second_join['crash_count_x'].fillna(0, inplace = True)
second_join['crash_count_y'].fillna(0, inplace = True)

second_join['total_crash'] = second_join['crash_count_x'] + second_join['crash_count_y']

print('Number of Records that are Null/NaN:', second_join['total_crash'].isna().sum())
# Out:
# dfpivot 34 records
# 15
# dfpivot2 10 records
# First Join 50
# Second_Join 50
# Number of Records that are Null/NaN: 0

# %%
second_join.to_csv('../data/output/crash/bicycle_crash.csv')
